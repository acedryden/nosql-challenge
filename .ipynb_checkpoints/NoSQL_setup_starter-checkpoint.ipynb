# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# Import the dataset with: "!mongoimport --type json -d Resources -c establishments --drop --jsonArray "C:\Users\dryde\OneDrive\Documents\GitHub\nosql-challenge\Resources\establishments.json"`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#Import Data
# !mongoimport --type json -d Resources -c establishments --drop --jsonArray "C:\Users\dryde\OneDrive\Documents\GitHub\nosql-challenge\Resources\establishments.json"
# Out:
# 2024-02-08T09:52:36.615-0500	connected to: mongodb://localhost/
# 2024-02-08T09:52:36.616-0500	dropping: Resources.establishments
# 2024-02-08T09:52:37.717-0500	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# confirm that our new database was created
databases = mongo.list_database_names()
print("Available databases:")
for db in databases:
    print(db)
# Out:
# Available databases:
# Resources
# admin
# config
# epa
# fruitsDB
# local
# met
# petsitly_marketing
# test

# %%
# assign the uk_food database to a variable name
db_name = 'Resources' 
# assign the collection to a variable
collection_name = 'establishments' 
food_db = mongo[db_name][collection_name]

# %%
# review the collections in our new database
print(food_db)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Resources'), 'establishments')

# %%
# review a document in the establishments collection
# Query one document in the collection
one_doc = food_db.find_one()

# Print the document
pprint(one_doc)
# Out:
# {'AddressLine1': '3 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Boodles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.638929767669,
#  'FHRSID': 1349980,
#  'LocalAuthorityBusinessID': 'PI/000084064',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2021-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65c4eab41245e7e02b20ff3e'),
#  'geocode': {'latitude': '51.150879', 'longitude': '1.378536'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1349980',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
food_db.insert_one(penang)
# Out:
# InsertOneResult(ObjectId('65c4eab5bad72e85e76ea5af'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName":"Penang Flavours"}
results = food_db.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65c4eab5bad72e85e76ea5af'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessType': 1, 'BusinessTypeID': 1} 
businesstype_cursor = food_db.find(query, fields)
businesstype_list = list(businesstype_cursor)
pprint(businesstype_list)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff40')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff42')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff44')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff4e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff52')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff61')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff67')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff68')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff6b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff72')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff73')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff75')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff7c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff7d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff7e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff86')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff87')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff8b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff8c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff8f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff92')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff97')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ff99')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffa2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffa4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffa9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffaf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffb6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffb7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffb8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffbf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffc2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffc3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffc7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffc8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffc9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffcc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffd6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffe2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffe3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffeb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20ffef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20fffa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b20fffb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210002')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210005')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210007')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210008')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210009')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21000a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210016')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21001a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21001d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21002a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21002b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21002c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21002e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210038')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21003a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21003d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210041')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210042')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210050')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210051')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210055')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21005d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21005f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210060')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210066')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21006a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210073')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210076')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210077')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210079')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21007a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210080')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210083')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210086')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210088')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210089')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21008a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21008c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21008d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21008e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210090')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210091')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210093')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210095')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21009b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21009d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2100f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210103')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210104')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210105')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210109')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21010b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21010d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210118')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21011c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210123')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21012d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21013a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210159')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21015f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210161')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210166')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210168')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210172')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210179')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21018d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2101f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210204')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210205')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210209')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210217')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210218')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21021b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21021f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210224')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210232')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210236')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21023a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210240')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210247')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21024a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21024d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210256')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210258')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210259')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21025c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210268')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210272')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210276')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21027c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21027e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210282')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210284')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210285')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210286')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210287')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210288')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21028a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21028e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210291')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210293')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210294')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21029a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21029b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21029e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2102fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210303')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210309')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21030c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21030d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21030e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210311')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210312')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210313')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210318')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210319')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21031a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21031e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210329')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21032d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21032f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210332')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210333')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210335')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210337')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21033b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21033c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21033e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210341')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210342')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210346')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210348')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21034e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21034f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210358')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21035e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21036d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210374')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21037e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21037f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210383')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210386')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210387')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21039f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103fd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2103ff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210400')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210406')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21040f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210410')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210412')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210415')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210416')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21041a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21041f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210425')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210427')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21042b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21042d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210433')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210434')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210435')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210437')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210442')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210447')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21044c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210452')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210455')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210458')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210459')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21045e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210461')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21046a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21046e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210470')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210471')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210473')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210475')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210478')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210480')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210482')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210483')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210486')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21048c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21048d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210491')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210495')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210496')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210499')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21049a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21049c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21049d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21049e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21049f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b2104f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210504')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b21050a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210510')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210511')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210515')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab41245e7e02b210516')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
# ...
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219892')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219899')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21989a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21989c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2198ff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219900')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219907')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219908')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21990b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219915')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219933')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21993c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219941')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219944')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219946')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219947')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219949')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21994b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21994e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21994f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219950')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219951')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219952')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219964')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219965')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219974')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219976')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219979')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21997c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219987')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21998c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219991')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219993')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219994')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219995')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219999')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b21999b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b2199fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a00')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a02')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a0e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a0f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a11')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a17')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a1f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a21')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a23')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a28')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a30')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a34')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a40')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a43')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a48')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a4e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a66')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a67')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a7b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a85')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a87')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a8b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a90')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65c4eab51245e7e02b219a9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('65c4eab5bad72e85e76ea5af')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
filter_criteria = {'BusinessName': 'Penang Flavours'}
new_ID = {'$set': {'BusinessTypeID': '65c4eab41245e7e02b20ff3e'}}
result = food_db.update_one(filter_criteria, new_ID)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
results = food_db.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '65c4eab41245e7e02b20ff3e',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65c4eab5bad72e85e76ea5af'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
pprint(food_db.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
food_db.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
pprint(food_db.count_documents(query))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
food_db.find_one()
# Out:
# {'_id': ObjectId('65c4eab41245e7e02b210224'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
filter_criteria = {}
update_operation = [ { 
    '$set': {'latitude': {
        '$toDouble': {
            '$ifNull': [
                {'$toDecimal': '$latitude'}, 
                None
            ]}}, 
             'longitude': {
                 '$toDouble': {
                     '$ifNull': [
                         {'$toDecimal': '$longitude'}, 
                         None
                     ]}}}}]
result = food_db.update_many(filter_criteria, update_operation)

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
food_db.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
filter_criteria = {}
update_operation = [{    
    '$set': {
         'RatingValue': {
             '$toInt': {
                '$ifNull': [
                     {'$toDecimal': '$RatingValue'},
                     None]}}}}]
result = food_db.update_many(filter_criteria, update_operation)

# %%
# Check that the coordinates and rating value are now numbers
food_db.find_one()
# Out:
# {'_id': ObjectId('65c4eab41245e7e02b210224'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}],
#  'latitude': None,
#  'longitude': None}
